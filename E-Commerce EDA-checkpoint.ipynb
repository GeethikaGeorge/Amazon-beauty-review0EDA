# %% [markdown]
# # Amazon Beauty Reviews Dataset – Overview
#
# The Amazon Beauty Reviews Dataset contains over 701528 customer reviews from the beauty and personal care category on Amazon.
# It includes product metadata (ASIN, brand, verified purchase info), ratings, and detailed review texts.
#
# Goal: Perform data cleaning, EDA, and modeling to extract insights about product ratings, customer sentiment, and brand performance.
#
# Columns and Description
#  1.rating : Product rating (1–5)
#  2.title : Short summary/title of the review
#  3.text : Full text of the customer review
#  4.images : Image URLs (if any)
#  5.asin : Product identifier
#  6.parent_asin : Parent product identifier
#  7.user_id : Unique user identifier
#  8.timestamp : Review date/time
#  9.helpful_vote : Number of helpful votes received
#  10.verified_purchase : Boolean (True/False)
#
#  Source: [Hugging Face – jhan21/amazon-beauty-reviews-dataset](https://huggingface.co/datasets/jhan21/amazon-beauty-reviews-dataset)

# %% [markdown]
# #  Tasks to be Done

# %% [markdown]
# 1.DATA CLEANING
#       -Handfle Missing or Empty fields.
#       -Convert timestamps to readable date formats.
#       -Handle invalid values.
# 2.Exploratory data analysis
#         -Rating distribution.
#         -Most common review title and words.
#         -Most reviewed products.
#         -Relationship between helpful_vote and rating.
#         -Verified vs non-verified review analysis.
#         -Create sentiment label based on rating.
#         -Extract review length
#         -Convert timestamp to year/month for trendanalysis.
# 3.Visualization
#     -Bar chart of rating distribution.
#     -Word coud of positive,negative reviews
#     -Trend of review pver months/years.
#     -Average rating per product.
# 4.Conclusion
#     -Key insights from reviews.
#     -Brand or Product information.
#     -Suggestionsfor e-commerce optimization.
#     - Provide marketing recommendations (discount effect, popular product lines).

# %%
# !pip install datasets pandas numpy matplotlib seaborn
# Out:
# Collecting datasets
#   Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
# Requirement already satisfied: pandas in c:\users\geeth\anaconda3\lib\site-packages (1.2.4)
# Requirement already satisfied: numpy in c:\users\geeth\anaconda3\lib\site-packages (1.20.1)
# Requirement already satisfied: matplotlib in c:\users\geeth\anaconda3\lib\site-packages (3.3.4)
# Requirement already satisfied: seaborn in c:\users\geeth\anaconda3\lib\site-packages (0.11.1)
# Collecting xxhash
#   Downloading xxhash-3.6.0-cp38-cp38-win_amd64.whl (31 kB)
# Requirement already satisfied: filelock in c:\users\geeth\anaconda3\lib\site-packages (from datasets) (3.0.12)
# Collecting requests>=2.32.2
#   Downloading requests-2.32.4-py3-none-any.whl (64 kB)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\geeth\anaconda3\lib\site-packages (from datasets) (5.4.1)
# Collecting tqdm>=4.66.3
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Collecting pyarrow>=15.0.0
#   Downloading pyarrow-17.0.0-cp38-cp38-win_amd64.whl (25.2 MB)
# Collecting fsspec[http]<=2024.9.0,>=2023.1.0
#   Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
# Collecting aiohttp
#   Downloading aiohttp-3.10.11-cp38-cp38-win_amd64.whl (384 kB)
# Collecting dill<0.3.9,>=0.3.0
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
# Collecting huggingface-hub>=0.23.0
#   Downloading huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
# Requirement already satisfied: packaging in c:\users\geeth\anaconda3\lib\site-packages (from datasets) (20.9)
# Collecting multiprocess<0.70.17
#   Downloading multiprocess-0.70.16-py38-none-any.whl (132 kB)
# Collecting yarl<2.0,>=1.12.0
#   Downloading yarl-1.15.2-cp38-cp38-win_amd64.whl (84 kB)
# Collecting async-timeout<6.0,>=4.0
#   Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.1.0-cp38-cp38-win_amd64.whl (28 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\geeth\anaconda3\lib\site-packages (from aiohttp->datasets) (20.3.0)
# Collecting aiohappyeyeballs>=2.3.0
#   Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl (14 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.5.0-cp38-cp38-win_amd64.whl (51 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\geeth\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->datasets) (3.7.4.3)
# Collecting typing-extensions>=3.7.4.3
#   Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\geeth\anaconda3\lib\site-packages (from packaging->datasets) (2.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\geeth\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (1.26.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\geeth\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\geeth\anaconda3\lib\site-packages (from requests>=2.32.2->datasets) (2020.12.5)
# Collecting charset_normalizer<4,>=2
#   Downloading charset_normalizer-3.4.4-cp38-cp38-win_amd64.whl (106 kB)
# Requirement already satisfied: colorama in c:\users\geeth\anaconda3\lib\site-packages (from tqdm>=4.66.3->datasets) (0.4.4)
# Collecting propcache>=0.2.0
#   Downloading propcache-0.2.0-cp38-cp38-win_amd64.whl (45 kB)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\geeth\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\geeth\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\geeth\anaconda3\lib\site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\geeth\anaconda3\lib\site-packages (from matplotlib) (8.2.0)
# Requirement already satisfied: six in c:\users\geeth\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\geeth\anaconda3\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: scipy>=1.0 in c:\users\geeth\anaconda3\lib\site-packages (from seaborn) (1.6.2)
# Installing collected packages: typing-extensions, propcache, multidict, frozenlist, yarl, charset-normalizer, async-timeout, aiosignal, aiohappyeyeballs, tqdm, requests, fsspec, dill, aiohttp, xxhash, pyarrow, multiprocess, huggingface-hub, datasets
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.7.4.3
#     Uninstalling typing-extensions-3.7.4.3:
#       Successfully uninstalled typing-extensions-3.7.4.3
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.59.0
#     Uninstalling tqdm-4.59.0:
#       Successfully uninstalled tqdm-4.59.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 0.9.0
#     Uninstalling fsspec-0.9.0:
#       Successfully uninstalled fsspec-0.9.0
# Successfully installed aiohappyeyeballs-2.4.4 aiohttp-3.10.11 aiosignal-1.3.1 async-timeout-5.0.1 charset-normalizer-3.4.4 datasets-3.1.0 dill-0.3.8 frozenlist-1.5.0 fsspec-2024.9.0 huggingface-hub-0.36.0 multidict-6.1.0 multiprocess-0.70.16 propcache-0.2.0 pyarrow-17.0.0 requests-2.32.4 tqdm-4.67.1 typing-extensions-4.13.2 xxhash-3.6.0 yarl-1.15.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.9.1 requires ruamel-yaml, which is not installed.

# %%
from datasets import load_dataset

# Load the Amazon Beauty Reviews dataset
dataset = load_dataset("jhan21/amazon-beauty-reviews-dataset")

# Check available splits
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['rating', 'title', 'text', 'images', 'asin', 'parent_asin', 'user_id', 'timestamp', 'helpful_vote', 'verified_purchase'],
#         num_rows: 701528
#     })
# })

# %%
import pandas as pd

# Convert dataset to pandas DataFrame
df = dataset["train"].to_pandas()

# Display first few rows
df.head()
# Out:
#    rating                                      title  \
# 0       5  Such a lovely scent but not overpowering.
# 1       4     Works great but smells a little weird.
# 2       5                                       Yes!
# 3       1                          Synthetic feeling
# 4       5                                         A+
#
#                                                 text images        asin  \
# 0  This spray is really nice. It smells really go...     []  B00YQ6X8EO
# 1  This product does what I need it to do, I just...     []  B081TJ8YS3
# 2                          Smells good, feels great!     []  B07PNNCSP9
# 3                                     Felt synthetic     []  B09JS339BZ
# 4                                            Love it     []  B08BZ63GMJ
#
#   parent_asin                       user_id                timestamp  \
# 0  B00YQ6X8EO  AGKHLEW2SOWHNMFQIJGBECAF7INQ  2020-05-05 14:08:48.923
# 1  B081TJ8YS3  AGKHLEW2SOWHNMFQIJGBECAF7INQ  2020-05-04 18:10:55.070
# 2  B097R46CSY  AE74DYR3QUGVPZJ3P7RFWBGIX7XQ  2020-05-16 21:41:06.052
# 3  B09JS339BZ  AFQLNQNQYFWQZPJQZS6V3NZU4QBQ  2022-01-28 18:13:50.220
# 4  B08BZ63GMJ  AFQLNQNQYFWQZPJQZS6V3NZU4QBQ  2020-12-30 10:02:43.534
#
#    helpful_vote  verified_purchase
# 0             0               True
# 1             1               True
# 2             2               True
# 3             0               True
# 4             0               True

# %%
# Shape of dataset
df.shape
# Out:
# (701528, 10)

# %%
# Summary info
df.info()

# Check missing values
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 701528 entries, 0 to 701527
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   rating             701528 non-null  int64
#  1   title              701419 non-null  object
#  2   text               701346 non-null  object
#  3   images             701528 non-null  object
#  4   asin               701528 non-null  object
#  5   parent_asin        701528 non-null  object
#  6   user_id            701528 non-null  object
#  7   timestamp          701528 non-null  object
#  8   helpful_vote       701528 non-null  int64
#  9   verified_purchase  701528 non-null  bool
# dtypes: bool(1), int64(2), object(7)
# memory usage: 48.8+ MB
# rating                 0
# title                109
# text                 182
# images                 0
# asin                   0
# parent_asin            0
# user_id                0
# timestamp              0
# helpful_vote           0
# verified_purchase      0
# dtype: int64

# %%
# Basic stats
df.describe()
# Out:
#               rating   helpful_vote
# count  701528.000000  701528.000000
# mean        3.960245       0.923588
# std         1.494452       5.471391
# min         1.000000       0.000000
# 25%         3.000000       0.000000
# 50%         5.000000       0.000000
# 75%         5.000000       1.000000
# max         5.000000     646.000000

# %%
df_clean = df.copy()
# 1.1 Handle missing values in title and text
df_clean['title'] = df_clean['title'].fillna("No Title")
df_clean['text'] = df_clean['text'].fillna("No Review Text")
# 1.2 Convert timestamp to datetime
df_clean['timestamp'] = pd.to_datetime(df_clean['timestamp'], errors='coerce')

# 1.3 Handle invalid or edge-case values
# Ratings must be between 1 and 5
df_clean = df_clean[(df_clean['rating'] >= 1) & (df_clean['rating'] <= 5)]

# Helpful votes cannot be negative
df_clean['helpful_vote'] = df_clean['helpful_vote'].clip(lower=0)

# 1.4 Remove rows where timestamp conversion failed
df_clean = df_clean.dropna(subset=['timestamp'])

df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 701528 entries, 0 to 701527
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   rating             701528 non-null  int64
#  1   title              701528 non-null  object
#  2   text               701528 non-null  object
#  3   images             701528 non-null  object
#  4   asin               701528 non-null  object
#  5   parent_asin        701528 non-null  object
#  6   user_id            701528 non-null  object
#  7   timestamp          701528 non-null  datetime64[ns]
#  8   helpful_vote       701528 non-null  int64
#  9   verified_purchase  701528 non-null  bool
# dtypes: bool(1), datetime64[ns](1), int64(2), object(6)
# memory usage: 54.2+ MB

# %%
# CHECK IF DUPLICATES EXIST 
duplicates = df_clean.duplicated(subset=['user_id', 'parent_asin', 'timestamp'])
duplicates.sum()
# Out:
# 7276

# %%
# VIEW DUPLICATE ROWS 
df_duplicates = df_clean[df_clean.duplicated(subset=['user_id', 'parent_asin', 'timestamp'], keep=False)]
df_duplicates
# Out:
#         rating                                              title  \
# 6565         5                                         Five Stars
# 6566         5                                         Five Stars
# 6713         5                              Moisturizing  ur skin
# 6714         5                              Useful For Showering.
# 6715         5                              Moisturizing  ur skin
# ...        ...                                                ...
# 701456       2                       Cute but not water resistant
# 701474       5  Easy replacement after i dumped a water bottle...
# 701477       5  Easy replacement after i dumped a water bottle...
# 701518       1                                           One Star
# 701519       1                                           One Star
#
#                                                      text images        asin  \
# 6565                                 Great for the price.     []  B00NT0AR7E
# 6566                                 Great for the price.     []  B00NT0AR7E
# 6713         Very pleasant smell and keeps ur skin Moist.     []  B00WDKPW9O
# 6714    Very Useful For Taking A Shower After My Opera...     []  B07VQZPHHF
# 6715         Very pleasant smell and keeps ur skin Moist.     []  B00WDKPW9O
# ...                                                   ...    ...         ...
# 701456  I think the design of the caps is so cute, but...     []  B08CDWBNWC
# 701474  I used nylon interior trim removal tools, from...     []  B07HC84V8D
# 701477  I used nylon interior trim removal tools, from...     []  B07HC84V8D
# 701518  Cant do anything with it. No Heat, cant get it...     []  B01HO3M2II
# 701519  Cant do anything with it. No Heat, cant get it...     []  B01HO3M2II
#
#        parent_asin                       user_id               timestamp  \
# 6565    B00NT0AR7E  AHT2QS6TYOXWKTNWDD63CMGOUZDQ 2015-09-25 22:07:06.000
# 6566    B00NT0AR7E  AHT2QS6TYOXWKTNWDD63CMGOUZDQ 2015-09-25 22:07:06.000
# 6713    B00WDKPW9O  AHLDHIVNLWLVRDISEB76TEMLOG2Q 2022-05-06 20:47:13.211
# 6714    B07VQZPHHF  AHLDHIVNLWLVRDISEB76TEMLOG2Q 2020-01-06 22:05:23.132
# 6715    B00WDKPW9O  AHLDHIVNLWLVRDISEB76TEMLOG2Q 2022-05-06 20:47:13.211
# ...            ...                           ...                     ...
# 701456  B08CDWBNWC  AGAM6PJOXCDJLLOPYJVFNILD7DTQ 2021-04-19 18:45:40.630
# 701474  B07HC84V8D  AHOBG6Y2ONNVVJJR54QLT3OIVMLA 2019-08-27 02:49:24.898
# 701477  B07HC84V8D  AHOBG6Y2ONNVVJJR54QLT3OIVMLA 2019-08-27 02:49:24.898
# 701518  B01HO3M2II  AF35ZHUHDHWFRMSP2BBRCTGBUMYA 2018-04-20 20:17:31.799
# 701519  B01HO3M2II  AF35ZHUHDHWFRMSP2BBRCTGBUMYA 2018-04-20 20:17:31.799
#
#         helpful_vote  verified_purchase sentiment  review_length  year  \
# 6565               0               True  Positive              4  2015
# 6566               0               True  Positive              4  2015
# 6713               0               True  Positive              8  2022
# 6714               1               True  Positive              9  2020
# 6715               0               True  Positive              8  2022
# ...              ...                ...       ...            ...   ...
# 701456             0               True  Negative             57  2021
# 701474             0               True  Positive             78  2019
# 701477             0               True  Positive             78  2019
# 701518             0               True  Negative             19  2018
# 701519             0               True  Negative             19  2018
#
#           month
# 6565    2015-09
# 6566    2015-09
# 6713    2022-05
# 6714    2020-01
# 6715    2022-05
# ...         ...
# 701456  2021-04
# 701474  2019-08
# 701477  2019-08
# 701518  2018-04
# 701519  2018-04
#
# [13415 rows x 14 columns]

# %%
# REMOVE DUPLICATES
df_no_duplicates = df_clean.drop_duplicates(subset=['user_id', 'parent_asin', 'timestamp'], keep='first')

# %%
# COMPARE SHAPES
df_clean.shape, df_no_duplicates.shape
# Out:
# ((701528, 14), (694252, 14))

# %%
df_duplicates.groupby(['parent_asin']).size().sort_values(ascending=False).head(10)
# Out:
# parent_asin
# B0BM4GX6TT    44
# B0C9CWKY9G    33
# B0BTLTVR1X    25
# B08L5KN7X4    25
# B01N4885PD    25
# B005BZQHEC    23
# B07C533XCW    23
# B00J7QCNDU    22
# B07Y6WBGQQ    21
# B09XBSDCXP    20
# dtype: int64

# %%
df_duplicates.groupby(['user_id']).size().sort_values(ascending=False).head(10)
# Out:
# user_id
# AHDVSLWHSORYGG3S5QZMVDFNOXUQ      108
# AFKZESU3PTCQ2UVDBDSFVFTXBFNQ_1     33
# AG3FVTSD7ISLKALIPY24IVJCCDTA       30
# AFKZESU3PTCQ2UVDBDSFVFTXBFNQ_2     24
# AGIS3QL3LUEQWKF3YKHLLWDD5BJA       16
# AFNZTWQNJR5ULPBOMJTUPSNOZMFA       12
# AF2JFLH4622DV2ROKFEUJIW5U5LA       12
# AEXFTGI4SM7I6NILK6ZWMLW6BLZA       10
# AG7S27ONM4W3F2IEUTTO3T3WFFQQ       10
# AHK3S32VWSXOBIYYF2MKGXUDRDBA       10
# dtype: int64

# %% [markdown]
# # EXPLOARATORY DATA ANALYSIS

# %%
#RATING DISTRIBUTION
import matplotlib.pyplot as plt

df_clean['rating'].value_counts().sort_index().plot(kind='bar')
plt.title("Rating Distribution")
plt.xlabel("Rating")
plt.ylabel("Count")
plt.show()

# %%
#MOST COMMON REVIE TITLES
df_clean['title'].value_counts().head(10)
# Out:
# Five Stars       48549
# Four Stars        9197
# One Star          7611
# Three Stars       5786
# Great product     4671
# Two Stars         4070
# Love it           3881
# Great             3621
# Good              2907
# Perfect           2441
# Name: title, dtype: int64

# %%
# MOST COMMON WORDS IN REVIEW TEXT
from collections import Counter
import re

words = " ".join(df_clean['text']).lower()
words = re.findall(r'\b[a-z]{3,}\b', words)  # remove short/common noise words

word_counts = Counter(words).most_common(20)
word_counts
# Out:
# [('the', 924390),
#  ('and', 695711),
#  ('this', 386924),
#  ('for', 322357),
#  ('but', 211080),
#  ('not', 204928),
#  ('hair', 188062),
#  ('that', 182488),
#  ('was', 179761),
#  ('with', 174163),
#  ('have', 168832),
#  ('you', 152023),
#  ('very', 144458),
#  ('product', 141436),
#  ('they', 137530),
#  ('great', 137068),
#  ('are', 134475),
#  ('love', 128360),
#  ('like', 127587),
#  ('use', 117164)]

# %%
# MOST REVIEWED PRODUCTS
df_clean['parent_asin'].value_counts().head(10)
# Out:
# B085BB7B1M    1962
# B0BM4GX6TT    1750
# B07C533XCW    1513
# B09X9BG4FC    1374
# B00R1TAN7I    1372
# B08L5KN7X4    1343
# B019GBG0IE    1328
# B01M1OFZOG    1243
# B0C9CWKY9G    1153
# B0107QYW14    1112
# Name: parent_asin, dtype: int64

# %%
# RELATIONSHIP B/W HWLPFUL VOTE AND RATING 
df_clean.groupby('rating')['helpful_vote'].mean()
# Out:
# rating
# 1    0.963852
# 2    0.748339
# 3    0.732005
# 4    0.930550
# 5    0.956071
# Name: helpful_vote, dtype: float64

# %%
# SCATTER PLOT
plt.scatter(df_clean['rating'], df_clean['helpful_vote'])
plt.title("Helpful Votes vs Rating")
plt.xlabel("Rating")
plt.ylabel("Helpful Votes")
plt.show()

# %%
# VERIFIED V/S NON-VERIFIED REVIEW ANALYSIS
verified_counts = df_clean['verified_purchase'].value_counts()

verified_avg_rating = df_clean.groupby('verified_purchase')['rating'].mean()

verified_counts, verified_avg_rating
# Out:
# (True     634969
#  False     66559
#  Name: verified_purchase, dtype: int64,
#  verified_purchase
#  False    4.075482
#  True     3.948166
#  Name: rating, dtype: float64)

# %%
# CRETAE SENTIMENTAL LABEL BASED ON RATING (4-5(POSITVE),3(NEUTRAL),1-2(NEGATIVE))
def sentiment_from_rating(r):
    if r >= 4:
        return "Positive"
    elif r == 3:
        return "Neutral"
    else:
        return "Negative"

df_clean['sentiment'] = df_clean['rating'].apply(sentiment_from_rating)

df_clean['sentiment'].value_counts()
# Out:
# Positive    500107
# Negative    145114
# Neutral      56307
# Name: sentiment, dtype: int64

# %%
# Extract Review Length
df_clean['review_length'] = df_clean['text'].apply(lambda x: len(x.split()))

df_clean[['text', 'review_length']].head()
# Out:
#                                                 text  review_length
# 0  This spray is really nice. It smells really go...             61
# 1  This product does what I need it to do, I just...             47
# 2                          Smells good, feels great!              4
# 3                                     Felt synthetic              2
# 4                                            Love it              2

# %%
# Convert Timestamp to Year / Month for Trend Analysis
df_clean['year'] = df_clean['timestamp'].dt.year
df_clean['month'] = df_clean['timestamp'].dt.to_period('M')

# Example: Reviews per year
df_clean['year'].value_counts().sort_index()
# Out:
# 2000         1
# 2001        12
# 2002        24
# 2003        56
# 2004       134
# 2005       267
# 2006       419
# 2007      1162
# 2008      1269
# 2009      1207
# 2010      1586
# 2011      1877
# 2012      2803
# 2013      7948
# 2014     16279
# 2015     36239
# 2016     62747
# 2017     68035
# 2018     72707
# 2019     99120
# 2020    126753
# 2021    124897
# 2022     61581
# 2023     14405
# Name: year, dtype: int64

# %%
# YEARLY TREND PLOT
df_clean.groupby('year').size().plot(kind='line')
plt.title("Review Count Per Year")
plt.xlabel("Year")
plt.ylabel("Number of Reviews")
plt.show()

# %%
# FINAL DATFRAME  STRUCTURE 
df_clean.head()
# Out:
#    rating                                      title  \
# 0       5  Such a lovely scent but not overpowering.
# 1       4     Works great but smells a little weird.
# 2       5                                       Yes!
# 3       1                          Synthetic feeling
# 4       5                                         A+
#
#                                                 text images        asin  \
# 0  This spray is really nice. It smells really go...     []  B00YQ6X8EO
# 1  This product does what I need it to do, I just...     []  B081TJ8YS3
# 2                          Smells good, feels great!     []  B07PNNCSP9
# 3                                     Felt synthetic     []  B09JS339BZ
# 4                                            Love it     []  B08BZ63GMJ
#
#   parent_asin                       user_id               timestamp  \
# 0  B00YQ6X8EO  AGKHLEW2SOWHNMFQIJGBECAF7INQ 2020-05-05 14:08:48.923
# 1  B081TJ8YS3  AGKHLEW2SOWHNMFQIJGBECAF7INQ 2020-05-04 18:10:55.070
# 2  B097R46CSY  AE74DYR3QUGVPZJ3P7RFWBGIX7XQ 2020-05-16 21:41:06.052
# 3  B09JS339BZ  AFQLNQNQYFWQZPJQZS6V3NZU4QBQ 2022-01-28 18:13:50.220
# 4  B08BZ63GMJ  AFQLNQNQYFWQZPJQZS6V3NZU4QBQ 2020-12-30 10:02:43.534
#
#    helpful_vote  verified_purchase sentiment  review_length  year    month
# 0             0               True  Positive             61  2020  2020-05
# 1             1               True  Positive             47  2020  2020-05
# 2             2               True  Positive              4  2020  2020-05
# 3             0               True  Negative              2  2022  2022-01
# 4             0               True  Positive              2  2020  2020-12
